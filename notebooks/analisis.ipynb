# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
github_data = pd.read_csv('/home/aidam/Desktop/github-repo-analysis/data/GitHub_Top_500_Repos_By_Stars.csv')

# %% [markdown]
# ### Tipos de datos
# - name: Nombre del repositorio (Categorico Nominal)
# - full_name: Nombre completo del repositorio (Categorico Nominal)
# - description: Descripcion del repositorio (Categorico nominal)
# - stars: Cantidad de estrellas del repositorio (Numerico continuo)
# - forks: Cantidad de forks al repsoritorio (Numerico continuo)
# - watchers: Cantidad de visualizaciones (Numerico continuo)
# - languaje: Lenguaje principal del proyecto
# - created_at: Fecha de creacion (Fecha)
# - updated_at: Fecha de ultima actualizacion (fecha)
# - open_issues:
# - license: Tipo de licencia del repositorio
# - topics: Topicos del repositorio
# - size_kb: Tamano del repositorio (Numerico continuo)
# - is_fork: Es forkeable el proyecto (Categorico binario)
# - archived: Repositorio archivado (Categorico binario)
# - homepage: direccion de los creadores del repositorio

# %%
github_data.head()
# Out:
#                      name                               full_name  \
# 0        build-your-own-x        codecrafters-io/build-your-own-x
# 1                 awesome                    sindresorhus/awesome
# 2            freeCodeCamp               freeCodeCamp/freeCodeCamp
# 3             public-apis                 public-apis/public-apis
# 4  free-programming-books  EbookFoundation/free-programming-books
#
#                                          description   stars  forks  watchers  \
# 0  Master programming by recreating your favorite...  487558  45879    487558
# 1  😎 Awesome lists about all kinds of interesting...  453265  34050    453265
# 2  freeCodeCamp.org's open-source codebase and cu...  442227  44188    442227
# 3                     A collective list of free APIs  420261  45730    420261
# 4         :books: Freely available programming books  385203  66095    385203
#
#      language            created_at            updated_at  open_issues  \
# 0    Markdown  2018-05-09T12:03:18Z  2026-04-08T22:08:47Z          461
# 1         NaN  2014-07-11T13:42:37Z  2026-04-08T22:13:57Z           59
# 2  TypeScript  2014-12-24T17:49:19Z  2026-04-08T22:09:14Z          200
# 3      Python  2016-03-20T23:49:42Z  2026-04-08T22:11:51Z         1216
# 4      Python  2013-10-11T06:50:37Z  2026-04-08T22:10:37Z           80
#
#         license                                             topics  size_kb  \
# 0           NaN  awesome-list, free, programming, tutorial-code...     1201
# 1       CC0-1.0  awesome, awesome-list, lists, resources, unicorns     1535
# 2  BSD-3-Clause  careers, certification, community, curriculum,...   559008
# 3           MIT  api, apis, dataset, development, free, list, l...     4962
# 4     CC-BY-4.0    books, education, hacktoberfest, list, resource    21200
#
#    is_fork  archived                                           homepage
# 0    False     False                            https://codecrafters.io
# 1    False     False                                                NaN
# 2    False     False                https://contribute.freecodecamp.org
# 3    False     False  https://APILayer.com/?utm_source=Github&utm_me...
# 4    False     False  https://ebookfoundation.github.io/free-program...
